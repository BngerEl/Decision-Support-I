# %%
using Pkg;

# %%
Pkg.upgrade_manifest()
# Out:
# Format of manifest file at `/home/jovyan/work/decision-support-i-23-24/Manifest.toml` already up to date: manifest_format == 2.0.0
#
# Stacktrace:
#  [1] pkgerror(msg::String)
#    @ Pkg.Types /opt/julia-1.9.0/share/julia/stdlib/v1.9/Pkg/src/Types.jl:69
#  [2] upgrade_manifest(ctx::Pkg.Types.Context)
#    @ Pkg.API /opt/julia-1.9.0/share/julia/stdlib/v1.9/Pkg/src/API.jl:2129
#  [3] upgrade_manifest()
#    @ Pkg.API /opt/julia-1.9.0/share/julia/stdlib/v1.9/Pkg/src/API.jl:2127
#  [4] top-level scope
#    @ In[2]:1

# %%
Pkg.add("JuMP")
Pkg.add("Cbc")
# Out:
#    Resolving package versions...
#   No Changes to `~/work/decision-support-i-23-24/Project.toml`
#   No Changes to `~/work/decision-support-i-23-24/Manifest.toml`
# Precompiling project...
#   ✓ JuMP
#   1 dependency successfully precompiled in 40 seconds. 35 already precompiled.
#    Resolving package versions...
#    Installed CoinUtils_jll ── v200.1100.600+0
#    Installed Cgl_jll ──────── v0.6000.600+0
#    Installed Clp_jll ──────── v100.1700.700+1
#    Installed MUMPS_seq_jll ── v500.600.100+0
#    Installed OpenBLAS32_jll ─ v0.3.21+0
#    Installed Osi_jll ──────── v0.10800.700+0
#    Installed Cbc_jll ──────── v200.1000.800+0
#    Installed Cbc ──────────── v1.2.0
#    Installed ASL_jll ──────── v0.1.3+0
#    Installed METIS_jll ────── v5.1.2+0
#     Updating `~/work/decision-support-i-23-24/Project.toml`
#   [9961bab8] + Cbc v1.2.0
#     Updating `~/work/decision-support-i-23-24/Manifest.toml`
#   [9961bab8] + Cbc v1.2.0
#   [ae81ac8f] + ASL_jll v0.1.3+0
# ...
